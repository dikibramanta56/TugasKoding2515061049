# %%
import numpy as np

# %%
#buat vector x dengan ukuran 3x1
x = np.array([25, 15, 49]) # type argument is optional, e.g.: dtype=np.float16
x
# Out:
# array([25, 15, 49])

# %%
#hitung panjang vector x
len(x)
# Out:
# 3

# %%
#tampilkan ukuran vector x
x.shape
# Out:
# (3,)

# %%
#tampilkan tipe data dari vector x
type(x)
# Out:
# numpy.ndarray

# %%
#akses elemen pertama dari vector x
x[0] # index ke 0
# Out:
# np.int64(25)

# %%
#tampilkan tipe data elemen pertama dari vector x
type(x[0])
# Out:
# numpy.int64

# %%
# 2 lakukan transpose pada vector x dan simpan pada variabel x_t
x_t = x.T
x_t
# Out:
# array([25, 15, 49])

# %%
#tampilkan ukuran dari vector x_t
x_t.shape
# Out:
# (3,)

# %%
#lakukan transpose pada vector y dan simpan pada variabel y_t
y = np.array([[25, 15, 49]])
y
y_t = y.T
y_t
# Out:
# array([[25],
#        [15],
#        [49]])

# %%
#tampilkan ukuran dari vector x_t
y_t.T.shape
# Out:
# (1, 3)

# %%
# 3 lakukan soal nomor 2 menggunakan pytorch dan tensorflow
import torch
import tensorflow as tf

# %%
x_pt = torch.tensor([25, 15, 49])
x_pt
# Out:
# tensor([25, 15, 49])

# %%
x_tf = tf.Variable([25, 15, 49])
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([25, 15, 49], dtype=int32)>
