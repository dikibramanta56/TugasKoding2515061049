# %%
import torch
import tensorflow as tf

# %%
# jelaskan tentang perintah ini
images_pt = torch.zeros([32, 28, 28, 3])

# %% [markdown]
# Perintah Images_pt = torch.zeros([32, 28, 28, 3]) di Google Colab menggunakan PyTorch untuk membuat sebuah tensor berisi nilai nol yang merepresentasikan 32 gambar kosong berukuran 28×28 piksel dengan 3 channel warna (RGB).
