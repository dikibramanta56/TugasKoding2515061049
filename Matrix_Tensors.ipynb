# %%
import numpy as np

# %%
# buat matrix X berukuran 2x3 menggunakan numpy
X = np.array([[25, 15], [61, 1], [0, 49]])
X
# Out:
# array([[25, 15],
#        [61,  1],
#        [ 0, 49]])

# %%
# tampilkan ukuran dari matrix X
X.shape
# Out:
# (3, 2)

# %%
# tampilkan seluruh elemen dari kolom pertama dari matrix X
X[:,0]
# Out:
# array([25, 61,  0])

# %%
# tampilkan seluruh elemen dari baris kedua dari matrix X
X[1,:]
# Out:
# array([61,  1])

# %%
# 2 ulangi soal nomor 1 menggunakan pytorch
import torch

# %%
X_pt = torch.tensor([[25, 15], [61, 1], [0, 49]])
X_pt
# Out:
# tensor([[25, 15],
#         [61,  1],
#         [ 0, 49]])

# %%
X_pt.shape
# Out:
# torch.Size([3, 2])

# %%
# seluruh elemen kolom pertama
X_pt[:,0]
# Out:
# tensor([25, 61,  0])

# %%
# seluruh elemen baris kedua
X_pt[1,:]
# Out:
# tensor([61,  1])

# %%
# ulangi soal nomor 1 menggunakan tensorflow
import tensorflow as tf

# %%
X_tf = tf.Variable([[25, 15], [61, 1], [0, 49]])
X_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3, 2) dtype=int32, numpy=
# array([[25, 15],
#        [61,  1],
#        [ 0, 49]], dtype=int32)>

# %%
X_tf.shape
# Out:
# TensorShape([3, 2])

# %%
# seluruh elemen kolom pertama
X_tf[:,0]
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([25, 61,  0], dtype=int32)>

# %%
# seluruh elemen baris kedua
X_tf[1,:]
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([61,  1], dtype=int32)>
